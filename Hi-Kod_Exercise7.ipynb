# %% [markdown]
# # Soru
# sozluk = {"Kategori": ["Giyim","Giyim", "Ayakkabı","Aksesuar","Ayakkabı","Giyim","Aksesuar","Aksesuar","Ayakkabı","Giyim"],
#   "Ürün" : ["Kazak","T-shirt","Sandalet","Küpe","Spor Ayakkabı","Pantolon","Kolye","Yüzük","Çizme","Ceket"],
# "Fiyat" : [300,180,450,50,700,400,150,80,850,900]}
#
#
# - Yukarıdaki sözlük DataFrame’e dönüştürülür.
# - Yukarıdaki DataFrame için
# - 2.indexte bulunan kategori bulunur. (Sadece kategori bilgisi)
# - 2. indexte bulunan ürün bulunur. (Sadece ürün bilgisi)
# - 4.indexten 9.indexe kadar olan veriler bulunur. (Kategori,ürün,fiyat bilgisi beraber)
# - 1.indexten 6.indexe kadar olan ürünler bulunur. (Sadece ürün bilgisi)
#     - Yukarıdaki DataFrame için
# - Giyim kategorisinde bulunan ürünler gösterilir.
# - Ayakkabı kategorisinde bulunan ürünler gösterilir.
# - Aksesuar kategorisinde bulunan ürünler gösterilir.
#     - Yukarıdaki DataFrame için
# - Giyim kategorisinde fiyatı 300'den fazla olan ürünler gösterilir.
# - Ayakkabı kategorisinde fiyatı 600'den az olan ürünler gösterilir.
# - Aksesuar kategorisinde fiyatı 100'den fazla olan aksesuar gösterilir.

# %%
import pandas as pd

sozluk = {"Kategori": ["Giyim","Giyim", "Ayakkabı","Aksesuar","Ayakkabı","Giyim","Aksesuar","Aksesuar","Ayakkabı","Giyim"],
  "Ürün" : ["Kazak","T-shirt","Sandalet","Küpe","Spor Ayakkabı","Pantolon","Kolye","Yüzük","Çizme","Ceket"],
  "Fiyat" : [300,180,450,50,700,400,150,80,850,900]}

# Sözlüğü DataFrame'e dönüştürme
df = pd.DataFrame(sozluk)

# 2. indexteki kategori ve ürünü bulma
kategori_2 = df.loc[2, 'Kategori']
urun_2 = df.loc[2, 'Ürün']

# 4. indexten 9. indexe kadar olan verileri bulma
veriler_4_9 = df.loc[4:9]

# 1. indexten 6. indexe kadar olan ürünleri bulma
urunler_1_6 = df.loc[1:6, 'Ürün']

# Giyim kategorisinde bulunan ürünleri bulma
giyim_urunleri = df[df['Kategori'] == 'Giyim']

# Ayakkabı kategorisinde bulunan ürünleri bulma
ayakkabi_urunleri = df[df['Kategori'] == 'Ayakkabı']

# Aksesuar kategorisinde bulunan ürünleri bulma
aksesuar_urunleri = df[df['Kategori'] == 'Aksesuar']

# Giyim kategorisinde fiyatı 300'den fazla olan ürünleri bulma
giyim_fiyat_300 = df[(df['Kategori'] == 'Giyim') & (df['Fiyat'] > 300)]

# Ayakkabı kategorisinde fiyatı 600'den az olan ürünleri bulma
ayakkabi_fiyat_600 = df[(df['Kategori'] == 'Ayakkabı') & (df['Fiyat'] < 600)]

# Aksesuar kategorisinde fiyatı 100'den fazla olan aksesuarları bulma
aksesuar_fiyat_100 = df[(df['Kategori'] == 'Aksesuar') & (df['Fiyat'] > 100)]

print("2. indexteki kategori:", kategori_2)
print("2. indexteki ürün:", urun_2)
print("4. indexten 9. indexe kadar olan veriler:")
print(veriler_4_9)
print("1. indexten 6. indexe kadar olan ürünler:")
print(urunler_1_6)
print("Giyim kategorisinde bulunan ürünler:")
print(giyim_urunleri)
print("Ayakkabı kategorisinde bulunan ürünler:")
print(ayakkabi_urunleri)
print("Aksesuar kategorisinde bulunan ürünler:")
print(aksesuar_urunleri)
print("Giyim kategorisinde fiyatı 300'den fazla olan ürünler:")
print(giyim_fiyat_300)
print("Ayakkabı kategorisinde fiyatı 600'den az olan ürünler:")
print(ayakkabi_fiyat_600)
print("Aksesuar kategorisinde fiyatı 100'den fazla olan aksesuarlar:")
print(aksesuar_fiyat_100)
