# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"./spotify_dataset.csv", encoding='Windows-1254')

df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.shape
# Out:
# (953, 24)

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df.describe().T
# Out:
#                       count         mean          std     min     25%     50%  \
# artist_count          953.0     1.556139     0.893044     1.0     1.0     1.0
# released_year         953.0  2018.238195    11.116218  1930.0  2020.0  2022.0
# released_month        953.0     6.033578     3.566435     1.0     3.0     6.0
# released_day          953.0    13.930745     9.201949     1.0     6.0    13.0
# in_spotify_playlists  953.0  5200.124869  7897.608990    31.0   875.0  2224.0
# in_spotify_charts     953.0    12.009444    19.575992     0.0     0.0     3.0
# in_apple_playlists    953.0    67.812172    86.441493     0.0    13.0    34.0
# in_apple_charts       953.0    51.908709    50.630241     0.0     7.0    38.0
# in_deezer_charts      953.0     2.666317     6.035599     0.0     0.0     0.0
# bpm                   953.0   122.540399    28.057802    65.0   100.0   121.0
# danceability_%        953.0    66.969570    14.630610    23.0    57.0    69.0
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# track_name              False
# artist(s)_name          False
# artist_count            False
# released_year           False
# released_month          False
# released_day            False
# in_spotify_playlists    False
# in_spotify_charts       False
# streams                 False
# in_apple_playlists      False
# in_apple_charts         False
# in_deezer_playlists     False
# in_deezer_charts        False
# in_shazam_charts         True
# bpm                     False
# key                      True
# mode                    False
# danceability_%          False
# valence_%               False
# energy_%                False
# acousticness_%          False
# instrumentalness_%      False
# liveness_%              False
# speechiness_%           False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df["artist(s)_name"].unique()
# Out:
# array(['Latto, Jung Kook', 'Myke Towers', 'Olivia Rodrigo',
#        'Taylor Swift', 'Bad Bunny', 'Dave, Central Cee',
#        'Eslabon Armado, Peso Pluma', 'Quevedo', 'Gunna',
#        'Peso Pluma, Yng Lvcas', 'Bad Bunny, Grupo Frontera', 'NewJeans',
#        'Miley Cyrus', 'David Kushner', 'Harry Styles', 'SZA',
#        'Fifty Fifty', 'Billie Eilish', 'Feid, Young Miko', 'Jimin',
#        'Gabito Ballesteros, Junior H, Peso Pluma', 'Arctic Monkeys',
#        'Bizarrap, Peso Pluma', 'The Weeknd, Madonna, Playboi Carti',
#        'Fuerza Regida', 'Rï¿½ï¿½ma, Selena G', 'Tainy, Bad Bunny',
#        'Morgan Wallen', 'Dua Lipa', 'Troye Sivan',
#        'Peso Pluma, Grupo Frontera',
#        'The Weeknd, 21 Savage, Metro Boomin', 'Karol G, Shakira',
#        'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#        'Yahritza Y Su Esencia, Grupo Frontera', 'Junior H, Peso Pluma',
#        'Post Malone, Swae Lee', 'Bebe Rexha, David Guetta',
# ...

# %%
df["released_year"].unique()
# Out:
# array([2023, 2019, 2022, 2013, 2014, 2018, 2017, 2020, 2016, 2012, 1999,
#        2008, 1975, 2021, 2015, 2011, 2004, 1985, 2007, 2002, 2010, 1983,
#        1992, 1968, 1984, 2000, 1997, 1995, 2003, 1973, 1930, 1994, 1958,
#        1957, 1963, 1959, 1970, 1971, 1952, 1946, 1979, 1950, 1942, 1986,
#        2005, 1991, 1996, 1998, 1982, 1987], dtype=int64)

# %%
df["in_spotify_playlists"].value_counts()
# Out:
# 1150     3
# 1112     3
# 356      3
# 86       3
# 3006     3
#         ..
# 2598     1
# 542      1
# 2459     1
# 10624    1
# 1320     1
# Name: in_spotify_playlists, Length: 879, dtype: int64

# %%
df.in_spotify_playlists.value_counts()
# Out:
# 1150     3
# 1112     3
# 356      3
# 86       3
# 3006     3
#         ..
# 2598     1
# 542      1
# 2459     1
# 10624    1
# 1320     1
# Name: in_spotify_playlists, Length: 879, dtype: int64

# %%
df["mode"].value_counts()
# Out:
# Major    550
# Minor    403
# Name: mode, dtype: int64

# %%
df["key"].value_counts()
# Out:
# C#    120
# G      96
# G#     91
# F      89
# B      81
# D      81
# A      75
# F#     73
# E      62
# A#     57
# D#     33
# Name: key, dtype: int64

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df_dropped = df.drop(['track_name','in_spotify_charts', 'artist(s)_name', 'artist_count', 'released_year','released_month'],axis=1)
df_dropped.head()
# Out:
#    released_day  in_spotify_playlists    streams  in_apple_playlists  \
# 0            14                   553  141381703                  43
# 1            23                  1474  133716286                  48
# 2            30                  1397  140003974                  94
# 3            23                  7858  800840817                 116
# 4            18                  3133  303236322                  84
#
#    in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts  \
# 0              263                  45                10              826
# 1              126                  58                14              382
# 2              207                  91                14              949
# 3              207                 125                12              548
# 4              133                  87                15              425
#
#    bpm key   mode  danceability_%  valence_%  energy_%  acousticness_%  \
# ...

# %%
df_dropped.head()
# Out:
#    released_day  in_spotify_playlists    streams  in_apple_playlists  \
# 0            14                   553  141381703                  43
# 1            23                  1474  133716286                  48
# 2            30                  1397  140003974                  94
# 3            23                  7858  800840817                 116
# 4            18                  3133  303236322                  84
#
#    in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts  \
# 0              263                  45                10              826
# 1              126                  58                14              382
# 2              207                  91                14              949
# 3              207                 125                12              548
# 4              133                  87                15              425
#
#    bpm key   mode  danceability_%  valence_%  energy_%  acousticness_%  \
# ...

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   released_day          953 non-null    int64
#  1   in_spotify_playlists  953 non-null    int64
#  2   streams               953 non-null    object
#  3   in_apple_playlists    953 non-null    int64
#  4   in_apple_charts       953 non-null    int64
#  5   in_deezer_playlists   953 non-null    object
#  6   in_deezer_charts      953 non-null    int64
#  7   in_shazam_charts      903 non-null    object
#  8   bpm                   953 non-null    int64
#  9   key                   858 non-null    object
#  10  mode                  953 non-null    object
#  11  danceability_%        953 non-null    int64
#  12  valence_%             953 non-null    int64
#  13  energy_%              953 non-null    int64
#  14  acousticness_%        953 non-null    int64
# ...

# %%
df_dropped["key"].value_counts().plot.barh()
# Out:
# <Axes: >

# %%
month_count = df_dropped["key"].value_counts().sort_index()
plt.bar(x = month_count.index, height= month_count.values)
# Out:
# <BarContainer object of 11 artists>

# %%
plt.figure(figsize=(10,5))

plt.bar(x = month_count.index, height= month_count.values)
plt.xlabel("key")
plt.ylabel("Count")
plt.title("Count of music by key")
# Out:
# Text(0.5, 1.0, 'Count of music by key')

# %%
plt.figure(figsize=(10,5))

sns.barplot(x = month_count.index, y= month_count.values)
plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Count of passanger by month")
# Out:
# Text(0.5, 1.0, 'Count of passanger by month')

# %%
df_dropped.head()
# Out:
#    released_day  in_spotify_playlists    streams  in_apple_playlists  \
# 0            14                   553  141381703                  43
# 1            23                  1474  133716286                  48
# 2            30                  1397  140003974                  94
# 3            23                  7858  800840817                 116
# 4            18                  3133  303236322                  84
#
#    in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts  \
# 0              263                  45                10              826
# 1              126                  58                14              382
# 2              207                  91                14              949
# 3              207                 125                12              548
# 4              133                  87                15              425
#
#    bpm key   mode  danceability_%  valence_%  energy_%  acousticness_%  \
# ...

# %%
df_dropped["key"].unique()
# Out:
# array(['B', 'C#', 'F', 'A', 'D', 'F#', nan, 'G#', 'G', 'E', 'A#', 'D#'],
#       dtype=object)

# %%
df_dropped.head
# Out:
# <bound method NDFrame.head of      released_day  in_spotify_playlists    streams  in_apple_playlists  \
# 0              14                   553  141381703                  43
# 1              23                  1474  133716286                  48
# 2              30                  1397  140003974                  94
# 3              23                  7858  800840817                 116
# 4              18                  3133  303236322                  84
# ..            ...                   ...        ...                 ...
# 948             3                   953   91473363                  61
# 949            21                  1180  121871870                   4
# 950             3                   573   73513683                   2
# 951            20                  1320  133895612                  29
# 952             4                   782   96007391                  27
#
#      in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts  \
# ...

# %%
import pandas as pd
import random

# Veri boyutunu belirle
data_size = 100  # Örnek için 100 veri noktası

# Rastgele veri oluşturma
data = {
    "in_spotify_playlists": [random.randint(0, 10) for _ in range(data_size)],
    "in_apple_playlists": [random.randint(0, 10) for _ in range(data_size)],
    "key": [random.choice(["C#","G","G#","F","B","D","A","F#","E","A#","D#"]) for _ in range(data_size)]
}

# Veriyi DataFrame'e dönüştürme
df = pd.DataFrame(data)

# Şimdi veri çerçevesini kullanarak benzer bir kod oluşturabilirsiniz
# Örnek bir işlem:
grouped_data = df.groupby(["key"])[["in_spotify_playlists", "in_apple_playlists"]].mean().reset_index()

# Oluşturulan veriyi gösterme
print(grouped_data.head())
# Out:
#   key  in_spotify_playlists  in_apple_playlists
# 0   A              4.818182            5.727273
# 1  A#              4.555556            3.444444
# 2   B              5.090909            5.727273
# 3  C#              5.800000            6.200000
# 4   D              5.300000            4.200000

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Çubuk grafik oluşturma
plt.figure(figsize=(10,12))
sns.barplot(x="in_spotify_playlists", y="in_apple_playlists", hue="key", data=data)
plt.title("Spotify ve Apple Müzik Listeleri Karşılaştırması")
plt.xlabel("Spotify Playlists")
plt.ylabel("Apple Music Playlists")

# Grafik gösterme
plt.show()
